# %% [markdown]
# # <img src="https://drive.google.com/uc?id=1E_GYlzeV8zomWYNBpQk0i00XcZjhoy3S" width="100"/>
# # Drill Week 6: Intro to ML
#
# In this drill, you will apply what you learned about high-level machine learning.
# You will use pandas and sklearn to explore a new dataset.
# You will instantiate, implement, and evaluate one of each of the following
# - SVM
# - MLP
# - K Nearest Neighbor
# - Decision Tree
#
# <img src="https://drive.google.com/uc?id=1wXJnftSIBkOYodRlRl0dxbonAUPgG-9W" height='400'>

# %% [markdown]
# # Drill
#
# Load in the Iris dataset using the provided code. As a breif intro, the iris dataset contains 3 classes (type of Iris). The features include petal length/width, sepal length/width

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
import pandas as pd
import numpy as np

# %%
# Load data
iris = datasets.load_iris()
X, y = iris.data[:, [0, 1]], iris.target
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2     0.0
# 1                4.9               3.0  ...               0.2     0.0
# 2                4.7               3.2  ...               0.2     0.0
# 3                4.6               3.1  ...               0.2     0.0
# 4                5.0               3.6  ...               0.2     0.0
#
# [5 rows x 5 columns]

# %% [markdown]
# Explore the data using .head .describe or .info
# What type of data is provided? How many features? Categorical or continuous? What is our target/label?

# %% [markdown]
# Perform a train/test split
# What is the purpose of a train test split?

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test =

# %% [markdown]
# Instantiate one of each of the following: SVM, Decision Tree, MLP (neural network), and KNN

# %%
svm = _
dt =  _
mlp = _
knn = _

# %% [markdown]
# Fit each model to the data!
# What does "fitting" a model with data do? Hint -- what happens to the parameters of a model?

# %%
#hint print(svm.____())

# %% [markdown]
# What are the scores for each? Which performs best?
# Can you gain insight into how decisions are made by the model?

# %%
#hint print(svm.____())

# %% [markdown]
# Final Recap: Give a brief description comparing how each model type determines the rules to discriminate between classes.
# Hint: What are the three ways to consider a  model that we discussed?
