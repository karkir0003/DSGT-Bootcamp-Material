# %% [markdown]
# #Apply What You Learned in Bootcamp!

# %% [markdown]
# Tip: refer back to the workshop if needed for similar examples and google is your best friend :)
# A lot of times, you won't know how to do something but there are a ton of online resources like the documentation of pandas methods or stackexchange posts by those who had similar questions like you.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive
# Out:
# /content/drive

# %%
# %ls
# Out:
# MyDrive/

# %%
#Switch your  directory to where our data is located! Add "Spring 2021 Bootcamp Material" folder as shortcut to drive at the MyDrive level
# %cd 'MyDrive/Spring 2021 Bootcamp Material/Participants/Data'
# Out:
# /content/drive/.shortcut-targets-by-id/14ismWEVuvc7ESkob1ObgVgyn9LoOSa3h/Spring 2021 Bootcamp Material/Participants/Data

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
#Q1

# %% [markdown]
# #Please attempt these problems before looking at the solution!

# %% [markdown]
# # Q1
# I want to find a dataframe that lists just the Age, Pclass, and Sex.
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Work space, scroll for solution

# %%
df[['Age','Pclass','Sex']]
# Out:
#       Age  Pclass     Sex
# 0    22.0       3    male
# 1    38.0       1  female
# 2    26.0       3  female
# 3    35.0       1  female
# 4    35.0       3    male
# ..    ...     ...     ...
# 886  27.0       2    male
# 887  19.0       1  female
# 888   NaN       3  female
# 889  26.0       1    male
# 890  32.0       3    male
#
# [891 rows x 3 columns]

# %% [markdown]
# # Q2
#
# The df below contains the range of all ages. Suppose I want the same 3 features, but this time, I only want to see people above the age of 30. Ultimately I would like a visual of people over thirty, but let's just focus on getting a dataframe for now.
#
# ![image.png](data:image/png;base64,...)

# %%
#workspace, scroll for solution

# %%
df[df['Age']>30][['Pclass','Sex','Age']]
# Out:
#      Pclass     Sex   Age
# 1         1  female  38.0
# 3         1  female  35.0
# 4         3    male  35.0
# 6         1    male  54.0
# 11        1  female  58.0
# ..      ...     ...   ...
# 873       3    male  47.0
# 879       1  female  56.0
# 881       3    male  33.0
# 885       3  female  39.0
# 890       3    male  32.0
#
# [305 rows x 3 columns]

# %% [markdown]
# # Q3
# I want to access the data of the 100th person, how would I do that?

# %%
#workspace, scroll for solution

# %%
df.iloc[99]
# Out:
# PassengerId                  100
# Survived                       0
# Pclass                         2
# Name           Kantor, Mr. Sinai
# Sex                         male
# Age                           34
# SibSp                          1
# Parch                          0
# Ticket                    244367
# Fare                          26
# Cabin                        NaN
# Embarked                       S
# Name: 99, dtype: object

# %% [markdown]
# # Q4
# Time to go back to the main dataframe, I would like to see how many unique ages there were, what function can I use to find that?

# %%
#workspace, scroll for solution

# %%
df['Age'].nunique()
# Out:
# 88

# %% [markdown]
# # Q5
# I was going through the dataframe and noticed cabin had a lot of null values, how can I see how many null values there are?
# While I'm at it, let me see how big this dataframe is as a whole.

# %%
#workspace, scroll for solution

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Q6
# That's a lot of missing values? It's probably best to just drop this. How do I drop a column?

# %%
#workspace, scroll for solution

# %%
df.drop('Cabin',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  ...            Ticket     Fare  Embarked
# 0              1         0       3  ...         A/5 21171   7.2500         S
# 1              2         1       1  ...          PC 17599  71.2833         C
# 2              3         1       3  ...  STON/O2. 3101282   7.9250         S
# 3              4         1       1  ...            113803  53.1000         S
# 4              5         0       3  ...            373450   8.0500         S
# ..           ...       ...     ...  ...               ...      ...       ...
# 886          887         0       2  ...            211536  13.0000         S
# 887          888         1       1  ...            112053  30.0000         S
# 888          889         0       3  ...        W./C. 6607  23.4500         S
# 889          890         1       1  ...            111369  30.0000         C
# 890          891         0       3  ...            370376   7.7500         Q
#
# [891 rows x 11 columns]

# %% [markdown]
# # Q7
# I want to see the distribution of people that survived within each class.
#
#
# Heads up, this is a little more coding heavy, and this is not the only way to do this.
#
# First: 0.6296296296296297
#
# Second: 0.47282608695652173
#
# Third: 0.24236252545824846

# %%
#workspace, scroll for solution

# %%
df = pd.read_csv('titanic_train.csv')

# %%
print("First:",str(df[df['Pclass'] == 1][df['Survived'] == 1].shape[0]/df[df['Pclass'] == 1].shape[0]))
print("Second:",str(df[df['Pclass'] == 2][df['Survived'] == 1].shape[0]/df[df['Pclass'] == 2].shape[0]))
print("Third:",str(df[df['Pclass'] == 3][df['Survived'] == 1].shape[0]/df[df['Pclass'] == 3].shape[0]))
# Out:
# First: 0.6296296296296297
# Second: 0.47282608695652173
# Third: 0.24236252545824846
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
df[df['Pclass'] == 2].shape
# Out:
# (184, 12)

# %%
df[df['Pclass'] == 2][df['Survived'] == 1].shape[0]/df[df['Pclass'] == 2].shape[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 0.47282608695652173

# %%
df.iloc[0]['Pclass']
# Out:
# 3

# %% [markdown]
# ## Groupby
# Groupby is a very useful method that lets us group dataframes by a feature

# %%
df = pd.read_csv('titanic_train.csv')

# %%
df.groupby('Sex').describe()
# Out:
#        PassengerId                          ...  Fare
#              count        mean         std  ...   50%    75%       max
# Sex                                         ...
# female       314.0  431.028662  256.846324  ...  23.0  55.00  512.3292
# male         577.0  454.147314  257.486139  ...  10.5  26.55  512.3292
#
# [2 rows x 56 columns]

# %%
df.groupby('Sex').mean()
# Out:
#         PassengerId  Survived    Pclass  ...     SibSp     Parch       Fare
# Sex                                      ...
# female   431.028662  0.742038  2.159236  ...  0.694268  0.649682  44.479818
# male     454.147314  0.188908  2.389948  ...  0.429809  0.235702  25.523893
#
# [2 rows x 7 columns]

# %%
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  ...  Ticket  Fare  Cabin  Embarked
# Sex                                          ...
# female          314       314     314   314  ...     314   314     97       312
# male            577       577     577   577  ...     577   577    107       577
#
# [2 rows x 11 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.groupby('Pclass')['Survived'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
df.groupby('Pclass').mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
df.groupby('Pclass').mean()['Survived'].plot(kind='bar')
